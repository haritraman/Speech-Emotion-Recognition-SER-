# %% [markdown]
# <a href="https://colab.research.google.com/github/haritraman/Speech-Emotion-Recognition-SER-/blob/main/SER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- Run this cell only ONCE per session ---

# 1. Install Dependencies
print("Installing the required 'resampy' library...")
# !pip install -q resampy
print("✅ Installation complete.")

# 2. Import Libraries
import os
import zipfile
import librosa
import numpy as np
import time
from google.colab import drive
from sklearn.model_selection import train_test_split
from sklearn.preprocessing impot LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Conv1D, MaxPooling1D, LSTM
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# 3. Mount Google Drive
print("\nMounting Google Drive...")
try:
    drive.mount('/content/drive', force_remount=True)
    print("✅ Drive mounted successfully.")
except Exception as e:
    print(f"🚨 Error mounting drive: {e}")
    raise

# 4. Unzip the Dataset
# 🔴 IMPORTANT: Update this path to where your archive.zip is located in Google Drive
zip_file_path = '/content/drive/MyDrive/SER_Project/datasets/ravdess'
extract_dir = '/content/drive/MyDrive/SER_Project/datasets/ravdess'

print(f"\nUnzipping '{zip_file_path}'...")
if not os.path.exists(extract_dir):
    try:
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_dir)
        print("✅ Unzipping complete.")
    except FileNotFoundError:
        print(f"🚨 ERROR: The file '{zip_file_path}' was not found.")
        print("Please make sure you have uploaded archive.zip and the path is correct.")
        raise
else:
    print("✅ Dataset already unzipped.")

# 5. Find the Correct Data Path
def find_dataset_folder(base_path):
    for dirpath, dirnames, filenames in os.walk(base_path):
        if 'Actor_01' in dirnames and 'Actor_24' in dirnames:
            print(f"✅ Dataset folder found at: {dirpath}")
            return dirpath
    return None

DATA_PATH = find_dataset_folder(extract_dir)
if DATA_PATH is None:
    print("🚨 ERROR: Could not automatically locate the RAVDESS dataset folder after unzipping.")
    raise FileNotFoundError("Dataset folder not found.")
# Out:
# Installing the required 'resampy' library...
# ✅ Installation complete.
#
# Mounting Google Drive...
# Mounted at /content/drive
# ✅ Drive mounted successfully.
#
# Unzipping '/content/drive/MyDrive/SER_Project/datasets/ravdess'...
# ✅ Dataset already unzipped.
# ✅ Dataset folder found at: /content/drive/MyDrive/SER_Project/datasets/ravdess

# %%
# --- Run this cell to load, augment, and prepare your data ---

# 1. Install augmentation library
print("Installing 'audiomentations' library...")
# !pip install -q audiomentations
print("✅ Installation complete.")
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import tqdm # Import tqdm for the progress bar

# 2. Define the Augmentation Pipeline
augment = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    Shift(min_shift=-0.5, max_shift=0.5, p=0.5), # Changed min_fraction and max_fraction to min_shift and max_shift
])

# 3. Load Raw Audio Waves and Labels
def load_raw_data(data_path):
    raw_data = []
    labels = []
    emotion_map = { '01': 'neutral', '02': 'calm', '03': 'happy', '04': 'sad', '05': 'angry', '06': 'fearful', '07': 'disgust', '08': 'surprised' }
    start_time = time.time()
    print("\nLoading raw audio files...")
    global initial_sample_rate
    initial_sample_rate = None

    all_files = []
    for actor_folder in sorted(os.listdir(data_path)):
        if actor_folder.startswith('Actor_'):
            actor_path = os.path.join(data_path, actor_folder)
            for file_name in os.listdir(actor_path):
                if file_name.endswith('.wav'): # Ensure only process audio files
                     all_files.append(os.path.join(actor_path, file_name))


    for file_path in tqdm.tqdm(all_files, desc="Processing audio files"):
        try:
            file_name = os.path.basename(file_path)
            emotion_code = file_name.split('-')[2]
            emotion = emotion_map[emotion_code]
            audio_data, sample_rate = librosa.load(file_path, sr=None) # Load at original sample rate
            if initial_sample_rate is None:
                initial_sample_rate = sample_rate
            raw_data.append(audio_data)
            labels.append(emotion)
        except Exception as e: # Catching a broader Exception for robustness
            print(f"\nWarning: Could not process file {file_name}. Error: {e}")
            continue # Skip to the next file if an error occurs

    print(f"\n✅ Raw data loading completed in {time.time() - start_time:.2f} seconds.")
    return raw_data, np.array(labels)

X_raw, y_raw = load_raw_data(DATA_PATH)
if len(X_raw) == 0:
    raise ValueError("No audio data was loaded.")

# 4. Prepare Labels and Split Data BEFORE Feature Extraction
le = LabelEncoder()
y_encoded = le.fit_transform(y_raw)
y_categorical = to_categorical(y_encoded)
X_train_raw, X_test_raw, y_train, y_test = train_test_split(X_raw, y_categorical, test_size=0.2, random_state=42, stratify=y_categorical)

# 5. Apply Augmentation to the Training Set
print("\nAugmenting training data... (This may take a moment)")
X_train_augmented_audio = []
y_train_augmented = []
for i, audio in tqdm.tqdm(enumerate(X_train_raw), total=len(X_train_raw), desc="Augmenting training data"):
    # Add original audio
    X_train_augmented_audio.append(audio)
    y_train_augmented.append(y_train[i])

    # Add augmented audio
    augmented_audio = augment(samples=audio, sample_rate=initial_sample_rate)
    X_train_augmented_audio.append(augmented_audio)
    y_train_augmented.append(y_train[i])
print(f"\n✅ Augmentation complete. Training set size doubled to {len(X_train_augmented_audio)} samples.")

# 6. Extract MFCCs from ALL audio clips
def extract_features(audio_list):
    feature_list = []
    for audio in tqdm.tqdm(audio_list, desc="Extracting features"):
        mfccs = librosa.feature.mfcc(y=audio, sr=initial_sample_rate, n_mfcc=40)
        feature_list.append(mfccs)
    return feature_list

print("\nExtracting features from all datasets...")
X_train_features = extract_features(X_train_augmented_audio)
X_test_features = extract_features(X_test_raw)
print("\n✅ Feature extraction complete.")


# 7. Pad and Finalize Data Preparation
y_train_augmented = np.array(y_train_augmented)
max_pad_len = max(x.shape[1] for x in X_train_features + X_test_features)

def pad_features(features, max_len):
    padded = np.array([np.pad(feat, ((0, 0), (0, max_len - feat.shape[1])), mode='constant') for feat in features])
    return padded

print("\nPadding features...")
X_train_padded = pad_features(X_train_features, max_pad_len)
X_test_padded = pad_features(X_test_features, max_pad_len)
X_train_padded = X_train_padded.transpose((0, 2, 1))
X_test_padded = X_test_padded.transpose((0, 2, 1))

print("✅ Data is ready for training.")
print(f"Augmented training data shape: {X_train_padded.shape}")
print(f"Test data shape: {X_test_padded.shape}")
# Out:
# Installing 'audiomentations' library...
# ✅ Installation complete.
#
# Loading raw audio files...
# Processing audio files: 100%|██████████| 1440/1440 [10:37<00:00,  2.26it/s]
# ✅ Raw data loading completed in 637.97 seconds.
#
# Augmenting training data... (This may take a moment)
# Augmenting training data: 100%|██████████| 1152/1152 [01:25<00:00, 13.51it/s]
# ✅ Augmentation complete. Training set size doubled to 2304 samples.
#
# Extracting features from all datasets...
# Extracting features: 100%|██████████| 2304/2304 [00:51<00:00, 44.68it/s]
# Extracting features: 100%|██████████| 288/288 [00:05<00:00, 55.54it/s]
# ✅ Feature extraction complete.
#
# Padding features...
# ✅ Data is ready for training.
# Augmented training data shape: (2304, 495, 40)
# Test data shape: (288, 495, 40)

# %%
# --- This cell builds and trains the high-performance model ---

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Activation, BatchNormalization

# 1. Build the Deeper CNN/LSTM Model
model = Sequential([
    Conv1D(512, 5, padding='same', input_shape=(X_train_padded.shape[1], X_train_padded.shape[2])),
    Activation('relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=4),
    Dropout(0.2),

    Conv1D(512, 5, padding='same'),
    Activation('relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=4),
    Dropout(0.2),

    Conv1D(512, 5, padding='same'),
    Activation('relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=4),
    Dropout(0.2),

    LSTM(128),
    Dropout(0.3),

    Dense(y_categorical.shape[1], activation='softmax')
])
model.summary()

# 2. Compile the Model
opt = Adam(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# 3. Define Callbacks
model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_accuracy', mode='max', verbose=1)
early_stopping = EarlyStopping(monitor='val_accuracy', patience=15, verbose=1, restore_best_weights=True)

# 4. Train the Model
print("\n--- Starting Training for the High-Performance Model ---")
history = model.fit(X_train_padded, y_train_augmented,
                    batch_size=32,
                    epochs=100,
                    validation_data=(X_test_padded, y_test),
                    callbacks=[model_checkpoint, early_stopping],
                    verbose=2)
print("--- Model Training Finished ---\n")

# 5. Evaluate the Best Model
print("Evaluating the best performing model from the training run...")
score = model.evaluate(X_test_padded, y_test, verbose=0)
print(f"Final Test Accuracy (Best Model): {score[1]*100:.2f}%")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 495, 512)       │       102,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 495, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 495, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 123, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 123, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 123, 512)       │     1,311,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 123, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 123, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 30, 512)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 512)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 30, 512)        │     1,311,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 30, 512)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 30, 512)        │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 7, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 7, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 128)            │       328,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,060,744 (11.68 MB)
#  Trainable params: 3,057,672 (11.66 MB)
#  Non-trainable params: 3,072 (12.00 KB)
# --- Starting Training for the High-Performance Model ---
# Epoch 1/100
#
# Epoch 1: val_accuracy improved from -inf to 0.20486, saving model to best_model.keras
# 72/72 - 120s - 2s/step - accuracy: 0.2326 - loss: 1.9421 - val_accuracy: 0.2049 - val_loss: 1.9630
# Epoch 2/100
#
# Epoch 2: val_accuracy improved from 0.20486 to 0.34375, saving model to best_model.keras
# 72/72 - 103s - 1s/step - accuracy: 0.3351 - loss: 1.7197 - val_accuracy: 0.3438 - val_loss: 1.7201
# Epoch 3/100
#
# Epoch 3: val_accuracy improved from 0.34375 to 0.43750, saving model to best_model.keras
# 72/72 - 141s - 2s/step - accuracy: 0.3759 - loss: 1.6098 - val_accuracy: 0.4375 - val_loss: 1.5425
# Epoch 4/100
#
# Epoch 4: val_accuracy improved from 0.43750 to 0.44792, saving model to best_model.keras
# 72/72 - 144s - 2s/step - accuracy: 0.4401 - loss: 1.4885 - val_accuracy: 0.4479 - val_loss: 1.4758
# Epoch 5/100
#
# Epoch 5: val_accuracy improved from 0.44792 to 0.47222, saving model to best_model.keras
# 72/72 - 139s - 2s/step - accuracy: 0.4844 - loss: 1.3854 - val_accuracy: 0.4722 - val_loss: 1.4515
# Epoch 6/100
#
# Epoch 6: val_accuracy improved from 0.47222 to 0.50347, saving model to best_model.keras
# 72/72 - 101s - 1s/step - accuracy: 0.5091 - loss: 1.3264 - val_accuracy: 0.5035 - val_loss: 1.4086
# Epoch 7/100
#
# Epoch 7: val_accuracy improved from 0.50347 to 0.51042, saving model to best_model.keras
# 72/72 - 103s - 1s/step - accuracy: 0.5660 - loss: 1.2051 - val_accuracy: 0.5104 - val_loss: 1.3935
# Epoch 8/100
#
# Epoch 8: val_accuracy improved from 0.51042 to 0.59722, saving model to best_model.keras
# 72/72 - 101s - 1s/step - accuracy: 0.5885 - loss: 1.1448 - val_accuracy: 0.5972 - val_loss: 1.1435
# Epoch 9/100
#
# Epoch 9: val_accuracy did not improve from 0.59722
# 72/72 - 101s - 1s/step - accuracy: 0.6419 - loss: 1.0303 - val_accuracy: 0.5938 - val_loss: 1.0799
# Epoch 10/100
#
# Epoch 10: val_accuracy improved from 0.59722 to 0.60764, saving model to best_model.keras
# 72/72 - 100s - 1s/step - accuracy: 0.6819 - loss: 0.9484 - val_accuracy: 0.6076 - val_loss: 1.0983
# Epoch 11/100
#
# Epoch 11: val_accuracy did not improve from 0.60764
# 72/72 - 102s - 1s/step - accuracy: 0.7018 - loss: 0.8814 - val_accuracy: 0.5451 - val_loss: 1.1984
# Epoch 12/100
#
# Epoch 12: val_accuracy did not improve from 0.60764
# 72/72 - 140s - 2s/step - accuracy: 0.7331 - loss: 0.8039 - val_accuracy: 0.5729 - val_loss: 1.0391
# Epoch 13/100
#
# Epoch 13: val_accuracy improved from 0.60764 to 0.64236, saving model to best_model.keras
# 72/72 - 142s - 2s/step - accuracy: 0.7721 - loss: 0.7085 - val_accuracy: 0.6424 - val_loss: 0.9778
# Epoch 14/100
#
# Epoch 14: val_accuracy improved from 0.64236 to 0.70139, saving model to best_model.keras
# 72/72 - 141s - 2s/step - accuracy: 0.7747 - loss: 0.6607 - val_accuracy: 0.7014 - val_loss: 0.7861
# Epoch 15/100
#
# Epoch 15: val_accuracy did not improve from 0.70139
# 72/72 - 99s - 1s/step - accuracy: 0.8082 - loss: 0.5848 - val_accuracy: 0.6424 - val_loss: 1.0603
# Epoch 16/100
#
# Epoch 16: val_accuracy did not improve from 0.70139
# 72/72 - 144s - 2s/step - accuracy: 0.8225 - loss: 0.5460 - val_accuracy: 0.6979 - val_loss: 0.8415
# Epoch 17/100
#
# Epoch 17: val_accuracy did not improve from 0.70139
# 72/72 - 139s - 2s/step - accuracy: 0.8451 - loss: 0.4926 - val_accuracy: 0.6597 - val_loss: 0.9738
# Epoch 18/100
#
# Epoch 18: val_accuracy improved from 0.70139 to 0.73611, saving model to best_model.keras
# 72/72 - 98s - 1s/step - accuracy: 0.8620 - loss: 0.4321 - val_accuracy: 0.7361 - val_loss: 0.7212
# Epoch 19/100
#
# Epoch 19: val_accuracy did not improve from 0.73611
# 72/72 - 144s - 2s/step - accuracy: 0.8685 - loss: 0.3944 - val_accuracy: 0.6875 - val_loss: 0.9081
# Epoch 20/100
#
# Epoch 20: val_accuracy did not improve from 0.73611
# 72/72 - 140s - 2s/step - accuracy: 0.8928 - loss: 0.3495 - val_accuracy: 0.6007 - val_loss: 1.2602
# Epoch 21/100
#
# Epoch 21: val_accuracy improved from 0.73611 to 0.75694, saving model to best_model.keras
# 72/72 - 142s - 2s/step - accuracy: 0.8898 - loss: 0.3526 - val_accuracy: 0.7569 - val_loss: 0.6694
# Epoch 22/100
#
# Epoch 22: val_accuracy did not improve from 0.75694
# 72/72 - 143s - 2s/step - accuracy: 0.8963 - loss: 0.3274 - val_accuracy: 0.7500 - val_loss: 0.7062
# Epoch 23/100
#
# Epoch 23: val_accuracy did not improve from 0.75694
# 72/72 - 98s - 1s/step - accuracy: 0.9115 - loss: 0.2919 - val_accuracy: 0.6806 - val_loss: 0.9238
# Epoch 24/100
#
# Epoch 24: val_accuracy did not improve from 0.75694
# 72/72 - 143s - 2s/step - accuracy: 0.9227 - loss: 0.2488 - val_accuracy: 0.7188 - val_loss: 0.8054
# Epoch 25/100
#
# Epoch 25: val_accuracy did not improve from 0.75694
# 72/72 - 140s - 2s/step - accuracy: 0.9388 - loss: 0.2197 - val_accuracy: 0.6979 - val_loss: 0.9519
# Epoch 26/100
#
# Epoch 26: val_accuracy improved from 0.75694 to 0.76736, saving model to best_model.keras
# 72/72 - 143s - 2s/step - accuracy: 0.9466 - loss: 0.1827 - val_accuracy: 0.7674 - val_loss: 0.7463
# Epoch 27/100
#
# Epoch 27: val_accuracy did not improve from 0.76736
# 72/72 - 143s - 2s/step - accuracy: 0.9384 - loss: 0.2049 - val_accuracy: 0.7292 - val_loss: 0.8307
# Epoch 28/100
#
# Epoch 28: val_accuracy did not improve from 0.76736
# 72/72 - 141s - 2s/step - accuracy: 0.9410 - loss: 0.1936 - val_accuracy: 0.6667 - val_loss: 1.1514
# Epoch 29/100
#
# Epoch 29: val_accuracy did not improve from 0.76736
# 72/72 - 99s - 1s/step - accuracy: 0.9540 - loss: 0.1574 - val_accuracy: 0.7604 - val_loss: 0.8249
# Epoch 30/100
#
# Epoch 30: val_accuracy did not improve from 0.76736
# 72/72 - 99s - 1s/step - accuracy: 0.9653 - loss: 0.1386 - val_accuracy: 0.6771 - val_loss: 0.9829
# Epoch 31/100
#
# Epoch 31: val_accuracy did not improve from 0.76736
# 72/72 - 141s - 2s/step - accuracy: 0.9653 - loss: 0.1367 - val_accuracy: 0.7118 - val_loss: 0.8671
# Epoch 32/100
#
# Epoch 32: val_accuracy improved from 0.76736 to 0.77778, saving model to best_model.keras
# 72/72 - 145s - 2s/step - accuracy: 0.9631 - loss: 0.1346 - val_accuracy: 0.7778 - val_loss: 0.7253
# Epoch 33/100
#
# Epoch 33: val_accuracy did not improve from 0.77778
# 72/72 - 102s - 1s/step - accuracy: 0.9692 - loss: 0.1170 - val_accuracy: 0.7326 - val_loss: 0.9382
# Epoch 34/100
#
# Epoch 34: val_accuracy improved from 0.77778 to 0.79514, saving model to best_model.keras
# 72/72 - 138s - 2s/step - accuracy: 0.9727 - loss: 0.1029 - val_accuracy: 0.7951 - val_loss: 0.6271
# Epoch 35/100
#
# Epoch 35: val_accuracy did not improve from 0.79514
# 72/72 - 142s - 2s/step - accuracy: 0.9618 - loss: 0.1192 - val_accuracy: 0.7361 - val_loss: 0.9687
# Epoch 36/100
#
# Epoch 36: val_accuracy did not improve from 0.79514
# 72/72 - 101s - 1s/step - accuracy: 0.9774 - loss: 0.1016 - val_accuracy: 0.7604 - val_loss: 0.8483
# Epoch 37/100
#
# Epoch 37: val_accuracy did not improve from 0.79514
# 72/72 - 138s - 2s/step - accuracy: 0.9722 - loss: 0.0955 - val_accuracy: 0.7604 - val_loss: 0.8196
# Epoch 38/100
#
# Epoch 38: val_accuracy did not improve from 0.79514
# 72/72 - 142s - 2s/step - accuracy: 0.9796 - loss: 0.0851 - val_accuracy: 0.7708 - val_loss: 0.7772
# Epoch 39/100
#
# Epoch 39: val_accuracy did not improve from 0.79514
# 72/72 - 143s - 2s/step - accuracy: 0.9852 - loss: 0.0727 - val_accuracy: 0.7951 - val_loss: 0.7292
# Epoch 40/100
#
# Epoch 40: val_accuracy did not improve from 0.79514
# 72/72 - 98s - 1s/step - accuracy: 0.9861 - loss: 0.0666 - val_accuracy: 0.7639 - val_loss: 0.8479
# Epoch 41/100
#
# Epoch 41: val_accuracy did not improve from 0.79514
# 72/72 - 142s - 2s/step - accuracy: 0.9826 - loss: 0.0641 - val_accuracy: 0.7257 - val_loss: 1.0269
# Epoch 42/100
#
# Epoch 42: val_accuracy did not improve from 0.79514
# 72/72 - 142s - 2s/step - accuracy: 0.9822 - loss: 0.0643 - val_accuracy: 0.7396 - val_loss: 0.9676
# Epoch 43/100
#
# Epoch 43: val_accuracy did not improve from 0.79514
# 72/72 - 139s - 2s/step - accuracy: 0.9835 - loss: 0.0622 - val_accuracy: 0.7604 - val_loss: 0.8173
# Epoch 44/100
#
# Epoch 44: val_accuracy did not improve from 0.79514
# 72/72 - 145s - 2s/step - accuracy: 0.9805 - loss: 0.0707 - val_accuracy: 0.7708 - val_loss: 0.8015
# Epoch 45/100
#
# Epoch 45: val_accuracy did not improve from 0.79514
# 72/72 - 142s - 2s/step - accuracy: 0.9826 - loss: 0.0581 - val_accuracy: 0.7639 - val_loss: 0.9194
# Epoch 46/100
#
# Epoch 46: val_accuracy did not improve from 0.79514
# 72/72 - 98s - 1s/step - accuracy: 0.9805 - loss: 0.0695 - val_accuracy: 0.7778 - val_loss: 0.8670
# Epoch 47/100
#
# Epoch 47: val_accuracy did not improve from 0.79514
# 72/72 - 98s - 1s/step - accuracy: 0.9861 - loss: 0.0587 - val_accuracy: 0.7951 - val_loss: 0.8322
# Epoch 48/100
#
# Epoch 48: val_accuracy did not improve from 0.79514
# 72/72 - 141s - 2s/step - accuracy: 0.9891 - loss: 0.0452 - val_accuracy: 0.7326 - val_loss: 0.9691
# Epoch 49/100
#
# Epoch 49: val_accuracy improved from 0.79514 to 0.82639, saving model to best_model.keras
# 72/72 - 144s - 2s/step - accuracy: 0.9852 - loss: 0.0547 - val_accuracy: 0.8264 - val_loss: 0.6486
# Epoch 50/100
#
# Epoch 50: val_accuracy did not improve from 0.82639
# 72/72 - 99s - 1s/step - accuracy: 0.9926 - loss: 0.0362 - val_accuracy: 0.8160 - val_loss: 0.7065
# Epoch 51/100
#
# Epoch 51: val_accuracy did not improve from 0.82639
# 72/72 - 139s - 2s/step - accuracy: 0.9878 - loss: 0.0429 - val_accuracy: 0.8160 - val_loss: 0.7620
# Epoch 52/100
#
# Epoch 52: val_accuracy did not improve from 0.82639
# 72/72 - 142s - 2s/step - accuracy: 0.9913 - loss: 0.0359 - val_accuracy: 0.7847 - val_loss: 0.8352
# Epoch 53/100
#
# Epoch 53: val_accuracy did not improve from 0.82639
# 72/72 - 98s - 1s/step - accuracy: 0.9913 - loss: 0.0338 - val_accuracy: 0.7639 - val_loss: 0.8490
# Epoch 54/100
#
# Epoch 54: val_accuracy did not improve from 0.82639
# 72/72 - 141s - 2s/step - accuracy: 0.9891 - loss: 0.0412 - val_accuracy: 0.7986 - val_loss: 0.7649
# Epoch 55/100
#
# Epoch 55: val_accuracy did not improve from 0.82639
# 72/72 - 142s - 2s/step - accuracy: 0.9887 - loss: 0.0433 - val_accuracy: 0.7917 - val_loss: 0.8602
# Epoch 56/100
#
# Epoch 56: val_accuracy did not improve from 0.82639
# 72/72 - 97s - 1s/step - accuracy: 0.9852 - loss: 0.0557 - val_accuracy: 0.7882 - val_loss: 0.7622
# Epoch 57/100
#
# Epoch 57: val_accuracy did not improve from 0.82639
# 72/72 - 142s - 2s/step - accuracy: 0.9883 - loss: 0.0466 - val_accuracy: 0.8160 - val_loss: 0.6823
# Epoch 58/100
#
# Epoch 58: val_accuracy did not improve from 0.82639
# 72/72 - 142s - 2s/step - accuracy: 0.9913 - loss: 0.0357 - val_accuracy: 0.8125 - val_loss: 0.7171
# Epoch 59/100
#
# Epoch 59: val_accuracy did not improve from 0.82639
# 72/72 - 142s - 2s/step - accuracy: 0.9931 - loss: 0.0307 - val_accuracy: 0.8125 - val_loss: 0.6846
# Epoch 60/100
#
# Epoch 60: val_accuracy did not improve from 0.82639
# 72/72 - 144s - 2s/step - accuracy: 0.9891 - loss: 0.0388 - val_accuracy: 0.6944 - val_loss: 1.2313
# Epoch 61/100
#
# Epoch 61: val_accuracy did not improve from 0.82639
# 72/72 - 144s - 2s/step - accuracy: 0.9896 - loss: 0.0370 - val_accuracy: 0.7778 - val_loss: 0.8575
# Epoch 62/100
#
# Epoch 62: val_accuracy did not improve from 0.82639
# 72/72 - 143s - 2s/step - accuracy: 0.9913 - loss: 0.0332 - val_accuracy: 0.8056 - val_loss: 0.8658
# Epoch 63/100
#
# Epoch 63: val_accuracy did not improve from 0.82639
# 72/72 - 140s - 2s/step - accuracy: 0.9831 - loss: 0.0520 - val_accuracy: 0.7500 - val_loss: 0.9812
# Epoch 64/100
#
# Epoch 64: val_accuracy did not improve from 0.82639
# 72/72 - 101s - 1s/step - accuracy: 0.9852 - loss: 0.0479 - val_accuracy: 0.7986 - val_loss: 0.7795
# Epoch 64: early stopping
# Restoring model weights from the end of the best epoch: 49.
# --- Model Training Finished ---
#
# Evaluating the best performing model from the training run...
# Final Test Accuracy (Best Model): 82.64%

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt


# Get predictions
y_pred = model.predict(X_test_padded)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=le.classes_,
            yticklabels=le.classes_,
            cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 585ms/step

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy/loss
plt.figure(figsize=(12, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training vs Validation Accuracy')

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training vs Validation Loss')

plt.show()

# %%
import librosa.display

# Pick one raw audio sample from training
sample_audio = X_train_raw[0]
plt.figure(figsize=(12, 4))
D = librosa.amplitude_to_db(np.abs(librosa.stft(sample_audio)), ref=np.max)
librosa.display.specshow(D, sr=initial_sample_rate, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (log scale)")
plt.show()

# %%
# Extract MFCC for visualization
mfcc = librosa.feature.mfcc(y=sample_audio, sr=initial_sample_rate, n_mfcc=40)
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfcc, x_axis='time', cmap='viridis')
plt.colorbar()
plt.title("MFCC Heatmap")
plt.tight_layout()
plt.show()
